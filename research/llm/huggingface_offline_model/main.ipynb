# %% [markdown]
# #### GPT2

# %%
# GPT2 : downloaded via wget (login not needed)
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load model from the local folder
model = AutoModelForCausalLM.from_pretrained("../../../models/gpt2")
tokenizer = AutoTokenizer.from_pretrained("../../../models/gpt2")

# Set device for Apple Silicon
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
model.to(device)

# Example text generation
text = "What is the capital of Paris?"
inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_length=50)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("\nGenerated Text:\n", generated_text)
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '../../../models/gpt2'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 6
#       3 import torch
#       5 # Load model from the local folder
# ----> 6 model = AutoModelForCausalLM.from_pretrained("../../../models/gpt2")
#       7 tokenizer = AutoTokenizer.from_pretrained("../../../models/gpt2")
#       9 # Set device for Apple Silicon
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:487, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     484 if commit_hash is None:
#     485     if not isinstance(config, PretrainedConfig):
#     486         # We make a call to the config file first (which may be absent) to get the commit hash as soon as possible
# --> 487         resolved_config_file = cached_file(
#     488             pretrained_model_name_or_path,
#     489             CONFIG_NAME,
#     490             _raise_exceptions_for_gated_repo=False,
#     491             _raise_exceptions_for_missing_entries=False,
#     492             _raise_exceptions_for_connection_errors=False,
#     493             **hub_kwargs,
#     494         )
#     495         commit_hash = extract_commit_hash(resolved_config_file, commit_hash)
#     496     else:
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/utils/hub.py:469, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     467     raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     468 except HFValidationError as e:
# --> 469     raise EnvironmentError(
#     470         f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     471     ) from e
#     472 return resolved_file
#
# OSError: Incorrect path_or_model_id: '../../../models/gpt2'. Please provide either the path to a local folder or the repo_id of a model on the Hub.

# %% [markdown]
# ### Mistral

# %%
# mistral: download via terminal login
# first download it for offline use 

#Download for offline use
from transformers import AutoModelForCausalLM, AutoTokenizer

model_name = "mistralai/Mistral-7B-Instruct-v0.3"

# Download model & tokenizer
model = AutoModelForCausalLM.from_pretrained(model_name, torch_dtype="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Save them locally
model.save_pretrained("./models/Mistral-7B-Instruct")
tokenizer.save_pretrained("./models/Mistral-7B-Instruct")

print("Model and tokenizer downloaded and saved locally.")
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 tokenizer = AutoTokenizer.from_pretrained(model_name)
#      13 # Save them locally
# ---> 14 model.save_pretrained("./models/Mistral-7B-Instruct")
#      15 tokenizer.save_pretrained("./models/Mistral-7B-Instruct")
#      17 print("Model and tokenizer downloaded and saved locally.")
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/modeling_utils.py:2980, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    2975     gc.collect()
#    2977 if safe_serialization:
#    2978     # At some point we will need to deal better with save_function (used for TPU and other distributed
#    2979     # joyfulness), but for now this enough.
# -> 2980     safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    2981 else:
#    2982     save_function(shard, os.path.join(save_directory, shard_file))
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/safetensors/torch.py:286, in save_file(tensors, filename, metadata)
#     255 def save_file(
#     256     tensors: Dict[str, torch.Tensor],
#     257     filename: Union[str, os.PathLike],
#     258     metadata: Optional[Dict[str, str]] = None,
#     259 ):
#     260     """
#     261     Saves a dictionary of tensors into raw bytes in safetensors format.
#     262
#    (...)
#     284     ```
#     285     """
# --> 286     serialize_file(_flatten(tensors), filename, metadata=metadata)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/safetensors/torch.py:500, in _flatten(tensors)
#     487 if failing:
#     488     raise RuntimeError(
#     489         f"""
#     490         Some tensors share memory, this will lead to duplicate memory on disk and potential differences when loading them again: {failing}.
#    (...)
#     493         """
#     494     )
#     496 return {
#     497     k: {
#     498         "dtype": str(v.dtype).split(".")[-1],
#     499         "shape": v.shape,
# --> 500         "data": _tobytes(v, k),
#     501     }
#     502     for k, v in tensors.items()
#     503 }
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/safetensors/torch.py:460, in _tobytes(tensor, name)
#     458     # Not in place as that would potentially modify a live running model
#     459     data = data.view(npdtype).byteswap(inplace=False)
# --> 460 return data.tobytes()
#
# KeyboardInterrupt:

# %%
# run the model offline 
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load model from local storage
# model = AutoModelForCausalLM.from_pretrained("../../../models/Mistral-7B-Instruct", torch_dtype="auto")
# Load model in 16-bit (FP16) instead of full precision
model = AutoModelForCausalLM.from_pretrained("../../../models/Mistral-7B-Instruct", torch_dtype=torch.float16)
tokenizer = AutoTokenizer.from_pretrained("../../../models/Mistral-7B-Instruct")

print("step1")
# Set device (M1/M2 Macs use 'mps', fallback to 'cpu' if not available)
device = torch.device("mps") if torch.backends.mps.is_available() else torch.device("cpu")
model.to(device)

print("step2")
# Example text generation
text = "Tell me a fun fact about space."
inputs = tokenizer(text, return_tensors="pt").to(device)
outputs = model.generate(**inputs, max_length=100)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("step3")
print("\nGenerated Text:\n", generated_text)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# step1
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# step2

# %% [markdown]
# ##### with GGUF + LLAMA

# %%
from llama_cpp import Llama

# model_path = "/Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Mistral-7B-Instruct-v0.3-Q6_K.gguf"
# model_path = "/Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Llama-3.3-70B-Instruct-Q2_K.gguf"
model_path = "/Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Nous-Hermes-13B.Q4_K_M.gguf"
llm = Llama(model_path=model_path)

output = llm("You are a teacher, you need to answer to my question in a short and concise sentence. Respond to this question: what is the capital of Japan?")

response = output["choices"][0]["text"].strip()  # Store the response as a string
print(response)  # Print or use it in your code
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M1 Pro) - 10922 MiB free
# llama_model_loader: loaded meta data with 20 key-value pairs and 363 tensors from /Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Nous-Hermes-13B.Q4_K_M.gguf (version GGUF V2)
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = nousresearch_nous-hermes-13b
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 13824
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 40
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 40
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv  10:                          general.file_type u32              = 15
# llama_model_loader: - kv  11:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  12:                      tokenizer.ggml.tokens arr[str,32001]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  13:                      tokenizer.ggml.scores arr[f32,32001]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  14:                  tokenizer.ggml.token_type arr[i32,32001]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  15:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  16:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  17:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  18:            tokenizer.ggml.padding_token_id u32              = 32000
# llama_model_loader: - kv  19:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type q4_K:  241 tensors
# llama_model_loader: - type q6_K:   41 tensors
# print_info: file format = GGUF V2
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 7.33 GiB (4.83 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      1 '<s>' is not marked as EOG
# load: control token:      2 '</s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 4
# load: token to piece cache size = 0.1684 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 2048
# print_info: n_embd           = 5120
# print_info: n_layer          = 40
# print_info: n_head           = 40
# print_info: n_head_kv        = 40
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 1
# print_info: n_embd_k_gqa     = 5120
# print_info: n_embd_v_gqa     = 5120
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-06
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: n_ff             = 13824
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 10000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 2048
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 13B
# print_info: model params     = 13.02 B
# print_info: general.name     = nousresearch_nous-hermes-13b
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32001
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: PAD token        = 32000 '[PAD]'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: layer   0 assigned to device CPU
# load_tensors: layer   1 assigned to device CPU
# load_tensors: layer   2 assigned to device CPU
# load_tensors: layer   3 assigned to device CPU
# load_tensors: layer   4 assigned to device CPU
# load_tensors: layer   5 assigned to device CPU
# load_tensors: layer   6 assigned to device CPU
# load_tensors: layer   7 assigned to device CPU
# load_tensors: layer   8 assigned to device CPU
# load_tensors: layer   9 assigned to device CPU
# load_tensors: layer  10 assigned to device CPU
# load_tensors: layer  11 assigned to device CPU
# load_tensors: layer  12 assigned to device CPU
# load_tensors: layer  13 assigned to device CPU
# load_tensors: layer  14 assigned to device CPU
# load_tensors: layer  15 assigned to device CPU
# load_tensors: layer  16 assigned to device CPU
# load_tensors: layer  17 assigned to device CPU
# load_tensors: layer  18 assigned to device CPU
# load_tensors: layer  19 assigned to device CPU
# load_tensors: layer  20 assigned to device CPU
# load_tensors: layer  21 assigned to device CPU
# load_tensors: layer  22 assigned to device CPU
# load_tensors: layer  23 assigned to device CPU
# load_tensors: layer  24 assigned to device CPU
# load_tensors: layer  25 assigned to device CPU
# load_tensors: layer  26 assigned to device CPU
# load_tensors: layer  27 assigned to device CPU
# load_tensors: layer  28 assigned to device CPU
# load_tensors: layer  29 assigned to device CPU
# load_tensors: layer  30 assigned to device CPU
# load_tensors: layer  31 assigned to device CPU
# load_tensors: layer  32 assigned to device CPU
# load_tensors: layer  33 assigned to device CPU
# load_tensors: layer  34 assigned to device CPU
# load_tensors: layer  35 assigned to device CPU
# load_tensors: layer  36 assigned to device CPU
# load_tensors: layer  37 assigned to device CPU
# load_tensors: layer  38 assigned to device CPU
# load_tensors: layer  39 assigned to device CPU
# load_tensors: layer  40 assigned to device CPU
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 362 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/41 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  7500.86 MiB
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 512
# llama_init_from_model: n_ctx_per_seq = 512
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 10000.0
# llama_init_from_model: freq_scale    = 1
# llama_init_from_model: n_ctx_per_seq (512) < n_ctx_train (2048) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M1 Pro
# ggml_metal_init: picking default device: Apple M1 Pro
# ggml_metal_init: using embedded metal library
# ggml_metal_init: GPU name:   Apple M1 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple7  (1007)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = false
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 11453.25 MB
# ggml_metal_init: loaded kernel_add                                    0x1077d6c70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                                0x115f5cc80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x1101edd90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row                                0x115d5ef10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x110e1d5b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                                0x110e18ab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x1101ee3f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row                                0x1101ed5e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x115f5d4c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x1101efc30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x1101ef6e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x117f4ce80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x110e17d80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x117f4dcb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x1372f92f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x117f4d4e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x1077d6ed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x1101f05f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x1101f18d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x115f5c770 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x115d53540 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x1372fa980 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x1372fb9e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x1077db2e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x1372fc560 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x1077dd620 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x1077ddbd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x1372fa470 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x115f5df80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x117f4e660 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x1101f2be0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x1077dce00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x115f5c2b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x115d60080 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x1077ded80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x115d54540 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x115d5f830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x1101f34c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x115d60f70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x1101f1eb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x1077e03a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x1077e1700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x1372fc160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x115d611d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x115d627b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x1101f3d30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x1372fcb30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x1077e0be0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x115f5f5e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x117f4e8c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x117f4ed70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x115f5eda0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x1101f5540 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x1101f4d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x1077e12b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x1101f6160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x1372fcfb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x1077e1b00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x1372feff0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x1372fd900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x115f61780 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x1372fe090 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x1077e2fd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x117f4f9c0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x117f502d0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x1372ffb60 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x115d61950 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x1077e3c50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x117f50c10 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x117f518c0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x117f4f550 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x117f51b20 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x115d62e90 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x117f51d80 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x1077e3600 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x1077e42c0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x1077e47e0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x117f528a0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x1077e4e20 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x115f628e0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x115d64170 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x117f52fd0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x1077e5080 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x1077e54a0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x1077e5e80 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x1101f4530 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x125c04a90 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x1077e6ea0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x115f62330 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x117f53b10 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x1077e77b0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x1077e7df0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x1077e8050 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x125c04680 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x117f55090 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x1101f6750 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x117f55850 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x1101f6e20 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x1077e8330 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x115f63750 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x125c05ac0 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x125e14b50 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x1101f69b0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x1101f77d0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x115f64220 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x115f64870 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x1101f9050 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x117f56440 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x125c05f00 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x115f64fc0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x1077e9720 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x115f65220 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x115d67330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x1077e8a40 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x1077e9080 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x115d682b0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x1101f8760 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x115f65560 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x1077eac90 | th_max =  448 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x117f57c80 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x117f58610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x1077e9f90 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x1077ebf00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x1077ea4d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x125c07510 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x1077ecb60 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x117f58d90 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x125c055a0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x117f592d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x117f5a310 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x117f5acc0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x117f59e70 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x117f5b5b0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x1077ecdc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x117f5c030 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x115f663b0 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x125c08b30 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x125c07e10 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x1077ed970 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x1101f9e30 | th_max =  448 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x125c0a9c0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x1077edbd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x125c0a5b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x115d665a0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x115d69c20 | th_max =  832 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x1101fb3d0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x1101fa2b0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x1077ee8d0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x1101fbed0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x1101fc130 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x125c0bb60 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x117f5c290 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x1077ef390 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x1077ee490 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x115d69800 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x125c0a190 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x1077efbc0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x1077f0560 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x117f5d260 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x1101fd0a0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x115d68da0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x125c0ca30 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x117f5df10 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x1077f00d0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f32                      0x1077f1cb0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f32                      0x1077f2640 | th_max =  832 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f32                     0x1077f3040 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f32                     0x117f5d6d0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f32                     0x1077f3d20 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f32                     0x117f5efb0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f32                     0x125c0d300 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f32                     0x117f5e740 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f32                     0x115d6bba0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f32                     0x115f67100 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f32                     0x1101fe140 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f32                     0x1101feb20 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f32                  0x1101ffc50 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f32                   0x117f5ff00 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f32                  0x125c0c2b0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f32                    0x125c0dfb0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f32                    0x1077f36f0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f32                    0x117f5f700 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f32                    0x1077f4d50 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f32                   0x1077f4390 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f32                   0x125c0f590 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x117f5f960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x1077f5ca0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x125e15f70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x1077f54f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x125c0e970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x115d6b270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x115f67710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x134004080 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x1101fdd30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x115d6b700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x115f68530 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x125c0fcf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x117f61190 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x1077f6b80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x125c11410 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x1077f7500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x1077f71d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x117f60cb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x115d6de40 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x125c11000 | th_max =  640 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x125c11c00 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x1077f89e0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x115d6e0a0 | th_max =  512 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x117f61d50 | th_max =  512 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x115e27970 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x115e28090 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x117f62080 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x117f62670 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x125e15130 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x1077f9380 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x134005b70 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x1077f99c0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x125c10860 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x125c12f00 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x117f62d00 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x115d6e9c0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x115f69450 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x125c13160 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x125c13de0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x134006230 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x117f63510 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x117f64330 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x117f647c0 | th_max =  576 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x125c14040 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x1077fa3d0 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x1077fa630 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x125c14df0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x117f64f60 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x125c14570 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x115d6f150 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x1077f83e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x125c16cf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x125c15cd0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x125c160e0 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x125c187e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x1340068a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x1340073e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x134007640 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x134007be0 | th_max =  768 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x134008f60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x1077fabf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x115f6a5e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x115f6b060 | th_max =  896 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x134009900 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x134009b60 | th_max =  704 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x13400a540 | th_max =  832 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x13400ad70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x115d6ff20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x115d71790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x115d720d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x115f6b2c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x125c19090 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x115d72b60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x115d72f70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x115d706b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x13400bdd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x115f6ad80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x13400c570 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x115d73970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x1077fc1d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x125c19850 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x115d74da0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x115d758f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x117f658e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x13400e150 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x13400b3b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x115f6c420 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 512, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 40, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 32: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 33: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 34: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 35: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 36: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 37: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 38: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init: layer 39: n_embd_k_gqa = 5120, n_embd_v_gqa = 5120
# llama_kv_cache_init:        CPU KV buffer size =   400.00 MiB
# llama_init_from_model: KV self size  =  400.00 MiB, K (f16):  200.00 MiB, V (f16):  200.00 MiB
# llama_init_from_model:        CPU  output buffer size =     0.12 MiB
# llama_init_from_model:        CPU compute buffer size =    85.01 MiB
# llama_init_from_model: graph nodes  = 1286
# llama_init_from_model: graph splits = 642 (with bs=512), 1 (with bs=1)
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | DOTPROD = 1 | LLAMAFILE = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.padding_token_id': '32000', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '40', 'llama.context_length': '2048', 'llama.attention.head_count': '40', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '13824', 'llama.embedding_length': '5120', 'llama.block_count': '40', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000001', 'general.name': 'nousresearch_nous-hermes-13b'}
# Using fallback chat format: llama-2
# llama_perf_context_print:        load time =   11809.87 ms
# llama_perf_context_print: prompt eval time =   11809.40 ms /    34 tokens (  347.34 ms per token,     2.88 tokens per second)
# llama_perf_context_print:        eval time =   89218.65 ms /     9 runs   ( 9913.18 ms per token,     0.10 tokens per second)
# llama_perf_context_print:       total time =  101036.78 ms /    43 tokens
# A: The capital of Japan is Tokyo.

# %%
response
# Out:
# 'The capital of Japan is Tokyo.'

# %%
from llama_cpp import Llama

# model_path = "/Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Mistral-7B-Instruct-v0.3-Q6_K.gguf"
# model_path = "/Users/firaterman/Documents/fer/models/models/Mistral-7B-Instruct/GGUF/Llama-3.3-70B-Instruct-Q2_K.gguf"
model_path = "/Users/firaterman/.lmstudio/models/lmstudio-community/gemma-3-12b-it-GGUF/gemma-3-12b-it-Q4_K_M.gguf"
llm = Llama(model_path=model_path)

output = llm("You are a teacher, you need to answer to my question in a short and concise sentence. Respond to this question: what is the capital of Japan?")

response = output["choices"][0]["text"].strip()  # Store the response as a string
print(response)  # Print or use it in your code
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M1 Pro) - 10915 MiB free
# llama_model_loader: loaded meta data with 40 key-value pairs and 626 tensors from /Users/firaterman/.lmstudio/models/lmstudio-community/gemma-3-12b-it-GGUF/gemma-3-12b-it-Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = gemma3
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Gemma 3 12b It
# llama_model_loader: - kv   3:                           general.finetune str              = it
# llama_model_loader: - kv   4:                           general.basename str              = gemma-3
# llama_model_loader: - kv   5:                         general.size_label str              = 12B
# llama_model_loader: - kv   6:                            general.license str              = gemma
# llama_model_loader: - kv   7:                   general.base_model.count u32              = 1
# llama_model_loader: - kv   8:                  general.base_model.0.name str              = Gemma 3 12b Pt
# llama_model_loader: - kv   9:          general.base_model.0.organization str              = Google
# llama_model_loader: - kv  10:              general.base_model.0.repo_url str              = https://huggingface.co/google/gemma-3...
# llama_model_loader: - kv  11:                               general.tags arr[str,1]       = ["image-text-to-text"]
# llama_model_loader: - kv  12:                      gemma3.context_length u32              = 131072
# llama_model_loader: - kv  13:                    gemma3.embedding_length u32              = 3840
# llama_model_loader: - kv  14:                         gemma3.block_count u32              = 48
# llama_model_loader: - kv  15:                 gemma3.feed_forward_length u32              = 15360
# llama_model_loader: - kv  16:                gemma3.attention.head_count u32              = 16
# llama_model_loader: - kv  17:    gemma3.attention.layer_norm_rms_epsilon f32              = 0.000001
# llama_model_loader: - kv  18:                gemma3.attention.key_length u32              = 256
# llama_model_loader: - kv  19:              gemma3.attention.value_length u32              = 256
# llama_model_loader: - kv  20:                      gemma3.rope.freq_base f32              = 1000000.000000
# llama_model_loader: - kv  21:            gemma3.attention.sliding_window u32              = 1024
# llama_model_loader: - kv  22:             gemma3.attention.head_count_kv u32              = 8
# llama_model_loader: - kv  23:                   gemma3.rope.scaling.type str              = linear
# llama_model_loader: - kv  24:                 gemma3.rope.scaling.factor f32              = 8.000000
# llama_model_loader: - kv  25:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  26:                         tokenizer.ggml.pre str              = default
# llama_model_loader: - kv  27:                      tokenizer.ggml.tokens arr[str,262144]  = ["<pad>", "<eos>", "<bos>", "<unk>", ...
# llama_model_loader: - kv  28:                      tokenizer.ggml.scores arr[f32,262144]  = [-1000.000000, -1000.000000, -1000.00...
# llama_model_loader: - kv  29:                  tokenizer.ggml.token_type arr[i32,262144]  = [3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  30:                tokenizer.ggml.bos_token_id u32              = 2
# llama_model_loader: - kv  31:                tokenizer.ggml.eos_token_id u32              = 1
# llama_model_loader: - kv  32:            tokenizer.ggml.unknown_token_id u32              = 3
# llama_model_loader: - kv  33:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  34:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  35:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  36:                    tokenizer.chat_template str              = {{ bos_token }}\n{%- if messages[0]['r...
# llama_model_loader: - kv  37:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - kv  38:               general.quantization_version u32              = 2
# llama_model_loader: - kv  39:                          general.file_type u32              = 15
# llama_model_loader: - type  f32:  289 tensors
# llama_model_loader: - type q4_K:  288 tensors
# llama_model_loader: - type q6_K:   49 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 6.79 GiB (4.96 BPW)
# llama_model_load: error loading model: error loading model architecture: unknown model architecture: 'gemma3'
# llama_model_load_from_file_impl: failed to load model
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 6
#       3 # model_path = "/Users/firaterman/Documents/fer/models/Mistral-7B-Instruct/GGUF/Mistral-7B-Instruct-v0.3-Q6_K.gguf"
#       4 # model_path = "/Users/firaterman/Documents/fer/models/models/Mistral-7B-Instruct/GGUF/Llama-3.3-70B-Instruct-Q2_K.gguf"
#       5 model_path = "/Users/firaterman/.lmstudio/models/lmstudio-community/gemma-3-12b-it-GGUF/gemma-3-12b-it-Q4_K_M.gguf"
# ----> 6 llm = Llama(model_path=model_path)
#       8 output = llm("You are a teacher, you need to answer to my question in a short and concise sentence. Respond to this question: what is the capital of Japan?")
#      10 response = output["choices"][0]["text"].strip()  # Store the response as a string
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/llama_cpp/llama.py:372, in Llama.__init__(self, model_path, n_gpu_layers, split_mode, main_gpu, tensor_split, rpc_servers, vocab_only, use_mmap, use_mlock, kv_overrides, seed, n_ctx, n_batch, n_ubatch, n_threads, n_threads_batch, rope_scaling_type, pooling_type, rope_freq_base, rope_freq_scale, yarn_ext_factor, yarn_attn_factor, yarn_beta_fast, yarn_beta_slow, yarn_orig_ctx, logits_all, embedding, offload_kqv, flash_attn, no_perf, last_n_tokens_size, lora_base, lora_scale, lora_path, numa, chat_format, chat_handler, draft_model, tokenizer, type_k, type_v, spm_infill, verbose, **kwargs)
#     367 if not os.path.exists(model_path):
#     368     raise ValueError(f"Model path does not exist: {model_path}")
#     370 self._model = self._stack.enter_context(
#     371     contextlib.closing(
# --> 372         internals.LlamaModel(
#     373             path_model=self.model_path,
#     374             params=self.model_params,
#     375             verbose=self.verbose,
#     376         )
#     377     )
#     378 )
#     380 # Override tokenizer
#     381 self.tokenizer_ = tokenizer or LlamaTokenizer(self)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/llama_cpp/_internals.py:56, in LlamaModel.__init__(self, path_model, params, verbose)
#      51     model = llama_cpp.llama_load_model_from_file(
#      52         self.path_model.encode("utf-8"), self.params
#      53     )
#      55 if model is None:
# ---> 56     raise ValueError(f"Failed to load model from file: {path_model}")
#      58 vocab = llama_cpp.llama_model_get_vocab(model)
#      60 if vocab is None:
#
# ValueError: Failed to load model from file: /Users/firaterman/.lmstudio/models/lmstudio-community/gemma-3-12b-it-GGUF/gemma-3-12b-it-Q4_K_M.gguf

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Check if CUDA is available and set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load model from local storage in FP16 for CUDA
model_path = "../../../models/Mistral-7B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    torch_dtype=torch.float16,  # Use FP16 for better performance
    device_map="auto"  # Automatically map model to GPU (if available)
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

print("Step 1: Model Loaded")

# Move model to the appropriate device (if "auto" isn't used)
model.to(device)

print("Step 2: Model moved to", device)

# Example text generation
text = "Tell me a fun fact about space."
inputs = tokenizer(text, return_tensors="pt").to(device)

# Generate output
with torch.no_grad():  # Disable gradients for inference
    outputs = model.generate(**inputs, max_length=100)

# Decode and print generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("Step 3: Generation complete")
print("\nGenerated Text:\n", generated_text)

# %%
import torch
print(torch.cuda.is_available())  # Should print True if CUDA is detected
print(torch.cuda.device_count())  # Number of available GPUs
print(torch.cuda.get_device_name(0))  # Name of the GPU
# Out:
# False
# 0
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(torch.cuda.is_available())  # Should print True if CUDA is detected
#       3 print(torch.cuda.device_count())  # Number of available GPUs
# ----> 4 print(torch.cuda.get_device_name(0))  # Name of the GPU
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/torch/cuda/__init__.py:491, in get_device_name(device)
#     479 def get_device_name(device: Optional[_device_t] = None) -> str:
#     480     r"""Get the name of a device.
#     481
#     482     Args:
#    (...)
#     489         str: the name of the device
#     490     """
# --> 491     return get_device_properties(device).name
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/torch/cuda/__init__.py:523, in get_device_properties(device)
#     511 def get_device_properties(device: Optional[_device_t] = None) -> _CudaDeviceProperties:
#     512     r"""Get the properties of a device.
#     513
#     514     Args:
#    (...)
#     521         _CudaDeviceProperties: the properties of the device
#     522     """
# --> 523     _lazy_init()  # will define _get_device_properties
#     524     device = _get_device_index(device, optional=True)
#     525     if device < 0 or device >= device_count():
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/torch/cuda/__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
T
# Check if CUDA is available and set device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

his step is giving me the error: requires the protobuf library but it was not found in your environment. checkout the instruction on the installation page
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
# Load model from local storage in FP16 for CUDA
model_path = "../../../models/Mistral-7B-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    torch_dtype=torch.float16,  # Use FP16 for better performance
    device_map="auto"  # Automatically map model to GPU (if available)
)

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_path)

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Load Phi-4 model from Hugging Face
model_name = "microsoft/Phi-4"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,  # Use FP16 for better performance
    device_map="auto"  # Automatically map model to GPU (if available)
)

tokenizer = AutoTokenizer.from_pretrained(model_name)

# Move model to GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Example inference
text = "Tell me a fun fact about space."
inputs = tokenizer(text, return_tensors="pt").to(device)

with torch.no_grad():
    outputs = model.generate(**inputs, max_length=100)

generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print("\nGenerated Text:\n", generated_text)
# Out:
# config.json:   0%|          | 0.00/802 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.4k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.93G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 # Load Phi-4 model from Hugging Face
#       5 model_name = "microsoft/Phi-4"
# ----> 7 model = AutoModelForCausalLM.from_pretrained(
#       8     model_name,
#       9     torch_dtype=torch.float16,  # Use FP16 for better performance
#      10     device_map="auto"  # Automatically map model to GPU (if available)
#      11 )
#      13 tokenizer = AutoTokenizer.from_pretrained(model_name)
#      15 # Move model to GPU
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/modeling_utils.py:3944, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3941 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3942 if is_sharded:
#    3943     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3944     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3945         pretrained_model_name_or_path,
#    3946         resolved_archive_file,
#    3947         cache_dir=cache_dir,
#    3948         force_download=force_download,
#    3949         proxies=proxies,
#    3950         resume_download=resume_download,
#    3951         local_files_only=local_files_only,
#    3952         token=token,
#    3953         user_agent=user_agent,
#    3954         revision=revision,
#    3955         subfolder=subfolder,
#    3956         _commit_hash=commit_hash,
#    3957     )
#    3959 if (
#    3960     is_safetensors_available()
#    3961     and isinstance(resolved_archive_file, str)
#    3962     and resolved_archive_file.endswith(".safetensors")
#    3963 ):
#    3964     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/utils/hub.py:1098, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1095 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1096     try:
#    1097         # Load from URL
# -> 1098         cached_filename = cached_file(
#    1099             pretrained_model_name_or_path,
#    1100             shard_filename,
#    1101             cache_dir=cache_dir,
#    1102             force_download=force_download,
#    1103             proxies=proxies,
#    1104             resume_download=resume_download,
#    1105             local_files_only=local_files_only,
#    1106             token=token,
#    1107             user_agent=user_agent,
#    1108             revision=revision,
#    1109             subfolder=subfolder,
#    1110             _commit_hash=_commit_hash,
#    1111         )
#    1112     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1113     # we don't have to catch them here.
#    1114     except EntryNotFoundError:
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/transformers/utils/hub.py:403, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     400 user_agent = http_user_agent(user_agent)
#     401 try:
#     402     # Load from URL or cache if already cached
# --> 403     resolved_file = hf_hub_download(
#     404         path_or_repo_id,
#     405         filename,
#     406         subfolder=None if len(subfolder) == 0 else subfolder,
#     407         repo_type=repo_type,
#     408         revision=revision,
#     409         cache_dir=cache_dir,
#     410         user_agent=user_agent,
#     411         force_download=force_download,
#     412         proxies=proxies,
#     413         resume_download=resume_download,
#     414         token=token,
#     415         local_files_only=local_files_only,
#     416     )
#     417 except GatedRepoError as e:
#     418     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/utils/_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/file_download.py:860, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     840     return _hf_hub_download_to_local_dir(
#     841         # Destination
#     842         local_dir=local_dir,
#    (...)
#     857         local_files_only=local_files_only,
#     858     )
#     859 else:
# --> 860     return _hf_hub_download_to_cache_dir(
#     861         # Destination
#     862         cache_dir=cache_dir,
#     863         # File info
#     864         repo_id=repo_id,
#     865         filename=filename,
#     866         repo_type=repo_type,
#     867         revision=revision,
#     868         # HTTP info
#     869         endpoint=endpoint,
#     870         etag_timeout=etag_timeout,
#     871         headers=hf_headers,
#     872         proxies=proxies,
#     873         token=token,
#     874         # Additional options
#     875         local_files_only=local_files_only,
#     876         force_download=force_download,
#     877     )
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1009, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1007 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1008 with WeakFileLock(lock_path):
# -> 1009     _download_to_tmp_and_move(
#    1010         incomplete_path=Path(blob_path + ".incomplete"),
#    1011         destination_path=Path(blob_path),
#    1012         url_to_download=url_to_download,
#    1013         proxies=proxies,
#    1014         headers=headers,
#    1015         expected_size=expected_size,
#    1016         filename=filename,
#    1017         force_download=force_download,
#    1018     )
#    1019     if not os.path.exists(pointer_path):
#    1020         _create_symlink(blob_path, pointer_path, new_blob=True)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/file_download.py:1543, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1540         _check_disk_space(expected_size, incomplete_path.parent)
#    1541         _check_disk_space(expected_size, destination_path.parent)
# -> 1543     http_get(
#    1544         url_to_download,
#    1545         f,
#    1546         proxies=proxies,
#    1547         resume_size=resume_size,
#    1548         headers=headers,
#    1549         expected_size=expected_size,
#    1550     )
#    1552 logger.info(f"Download complete. Moving file to {destination_path}")
#    1553 _chmod_and_move(incomplete_path, destination_path)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/huggingface_hub/file_download.py:452, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     450 new_resume_size = resume_size
#     451 try:
# --> 452     for chunk in r.iter_content(chunk_size=constants.DOWNLOAD_CHUNK_SIZE):
#     453         if chunk:  # filter out keep-alive new chunks
#     454             progress.update(len(chunk))
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/urllib3/response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/urllib3/response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~/Documents/fer/berserk3/lib/python3.12/site-packages/urllib3/response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.6/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:
